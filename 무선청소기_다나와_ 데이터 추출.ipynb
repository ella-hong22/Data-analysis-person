# %%
#크롤링 결과 가져오기 
import pandas as pd
data=pd.read_excel('G:/데이터분석 실무_08/datasalon-master/datasalon-master/6_Best_Product/3_1_danawa_crawling_result.xlsx')
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   상품명     400 non-null    object
#  1   스펙 목록   400 non-null    object
#  2   가격      400 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 9.5+ KB
#                          상품명  \
# 0            델로라 V11 파워 300W
# 1        LG전자 코드제로 A9S A9700
# 2  샤오미 차량용 청소기 무선 3세대 (해외구매)
# 3                 다이슨 V8 플러피
# 4        LG전자 코드제로 A9S A9300
#
#                                                스펙 목록       가격
# 0  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 29.6V / 헤파필터 / 싸...   134610
# 1  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단...  1031640
# 2  차량용청소기 / 무선 / 흡입력: 16,800Pa / 헤파필터 / 추가노즐: 틈새,...    59850
# 3  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.6V / 싸이클론 / 흡...   435610
# 4  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단...   669250

# %%
data['상품명'][:10]
# Out:
# 0                            델로라 V11 파워 300W
# 1                        LG전자 코드제로 A9S A9700
# 2                  샤오미 차량용 청소기 무선 3세대 (해외구매)
# 3                                 다이슨 V8 플러피
# 4                        LG전자 코드제로 A9S A9300
# 5                                샤오미 드리미 V10
# 6    샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 PRO (해외구매)
# 7                            다이슨 디지털 슬림 플러피+
# 8        샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 (해외구매)
# 9                            일렉트로룩스 ZB3302AK
# Name: 상품명, dtype: object

# %%
title="LG전자 코드제로 A9S A9700"
info=title.split(' ',1)
print(info)
# Out:
# ['LG전자', '코드제로 A9S A9700']

# %%
company_list=[]
product_list=[]
for title in data['상품명']:
    title_info=title.split(' ',1) #공백을 기준으로 1번째 것만 분리한다. 
    company_name=title_info[0]
    product_name=title_info[1]
    company_list.append(company_name)
    product_list.append(product_name)

# %%
print(len(data))
print(len(company_list))
print(company_list[:5])
print(len(product_list))
print(product_list[:5])
# Out:
# 400
# 400
# ['델로라', 'LG전자', '샤오미', '다이슨', 'LG전자']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-43bc1a45eb76> in <module>
#       2 print(len(company_list))
#       3 print(company_list[:5])
# ----> 4 print(len(product_iist))
#       5 print(product_list[:5])
#
# NameError: name 'product_iist' is not defined

# %%
data['스펙 목록'][0]
# Out:
# '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 29.6V / 헤파필터 / 싸이클론 / 4단계여과 / BLDC모터 / 흡입력: 22000Pa / 먼지통용량: 0.6L / 충전시간: 5시간 / 사용시간: 1시간10분 / 배터리: 리튬이온 / 용량: 2500mAh / 브러쉬: 바닥, 솔형, 틈새, 침구, 연장관 / LED라이트 / 거치대 / 무게: 3.89kg / 색상:레드, 블랙 / 소비전력: 300W / 크기(가로x세로x깊이): 239x1255x105mm'

# %%
print(data['스펙 목록'][3].split(' / '))
# Out:
# ['핸디/스틱청소기', '핸디+스틱형', '무선형', '전압: 21.6V', '싸이클론', '흡입력: 155AW', '충전시간: 5시간', '사용시간: 40분', '배터리: 리튬이온', '도킹스테이션', '무게: 2.58kg', '브러쉬: 소프트롤러클리너헤드, 미니모터, 소프트더스팅, 콤비네이션툴, 크레비스툴, 매트리스툴, 연장호스', '크기(가로x세로x깊이): 250x1264x224mm']

# %%
spec_list=data['스펙 목록'][0].split(' / ')
spec_list
# Out:
# ['핸디/스틱청소기',
#  '핸디+스틱형',
#  '무선형',
#  '전압: 29.6V',
#  '헤파필터',
#  '싸이클론',
#  '4단계여과',
#  'BLDC모터',
#  '흡입력: 22000Pa',
#  '먼지통용량: 0.6L',
#  '충전시간: 5시간',
#  '사용시간: 1시간10분',
#  '배터리: 리튬이온',
#  '용량: 2500mAh',
#  '브러쉬: 바닥, 솔형, 틈새, 침구, 연장관',
#  'LED라이트',
#  '거치대',
#  '무게: 3.89kg',
#  '색상:레드, 블랙',
#  '소비전력: 300W',
#  '크기(가로x세로x깊이): 239x1255x105mm']

# %%
category=spec_list[0]
category
# Out:
# '핸디/스틱청소기'

# %%
for spec in spec_list:
    if '사용시간' in spec:
        use_time_spec=spec
    elif '흡입력' in spec:
        suction_spec = spec
        
print(use_time_spec)
print(suction_spec)
# Out:
# 사용시간: 1시간10분
# 흡입력: 22000Pa

# %%
use_time_value = use_time_spec.split(' ')[1].strip()
# use_time_value = use_time_spec.split(' ')[0].strip()
suction_value = suction_spec.split(' ')[1].strip()

print(use_time_value)
print(suction_value)
# Out:
# 1시간10분
# 22000Pa

# %%
category_list=[]
use_time_list=[]
suction_list=[]

for spec_data in data['스펙 목록']:
    spec_list=spec_data.split(' / ')
    
    category=spec_list[0] #첫번째 카테고리만을 추출하기 위해
    category_list.append(category)
    
    ##사용시간, 흡입력 정보가 없는 제품을 위한 변수 생성 
    use_time_value=None
    suction_value=None
    
    
    for spec in spec_list:
        if '사용시간' in spec:
            use_time_value =spec.split(' ')[1].strip() #[1]인 이유 '사용시간: 00시간' 두개의 요소로 되어 있어서 두번째 원소를 추출하기위해
        if '흡입력' in spec:
            suction_value = spec.split(' ')[1].strip()
            
    use_time_list.append(use_time_value)
    suction_list.append(suction_value)

# %%
print("카테고리", len(category_list),category_list[0:5])
print("사용시간", len(use_time_list),use_time_list[0:5])
print("흡입력", len(suction_list),suction_list[0:5])
# Out:
# 카테고리 400 ['핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기']
# 사용시간 400 ['1시간10분', '2시간', '25분', '40분', '1시간']
# 흡입력 400 ['22000Pa', '200W', '16,800Pa', '155AW', '200W']

# %%
print("사용시간", len(use_time_list),use_time_list[0:5])
print("흡입력", len(suction_list),suction_list[0:5])
# Out:
# 사용시간 400 ['1시간10분', '2시간', '25분', '40분', '1시간']
# 흡입력 400 ['22000Pa', '200W', '16,800Pa', '155AW', '200W']

# %%
use_time_list
# Out:
# ['1시간10분',
#  '2시간',
#  '25분',
#  '40분',
#  '1시간',
#  '1시간',
#  '30분',
#  '40분',
#  '30분',
#  '42분',
#  '60분',
#  '2시간',
#  '1시간20분',
#  '80분',
#  '1시간',
#  '120분',
#  '2시간',
#  '45분',
#  '50분',
#  '30분',
#  '17분',
#  '60분',
#  '2시간',
#  '35분',
#  '2시간',
#  '1시간',
#  '1시간',
#  '60분',
#  '20분',
#  '1시간',
#  '60분',
#  '30분',
#  '2시간',
#  '45분',
#  '50분',
#  '42분',
#  '30분',
#  '48분',
#  '1시간30분',
#  '40분',
#  '30분',
#  '120분',
#  '1시간',
#  '10분',
#  '60분',
#  '50분',
#  None,
#  '1시간40분',
#  '24분',
#  '1시간40분',
#  '40분',
#  '40분',
#  '1시간',
#  '80분',
#  '30분',
#  '40분',
#  '2시간',
#  '80분',
#  '20분',
#  '12분',
#  '25분',
#  '30분',
#  '80분',
#  '30분',
#  '35분',
#  '48분',
#  '20분',
#  '42분',
#  '1시간20분',
#  '30분',
#  '40분',
#  '60분',
#  '1시간',
#  '40분',
#  '40분',
#  '30분',
#  '2시간',
#  '1시간5분',
#  '2시간',
#  '15분',
#  '40분(강),',
#  '40분',
#  '2시간',
#  '1시간',
#  '30분',
#  '25분',
#  '1시간',
#  '40분',
#  '40분',
#  '30분',
#  '80분',
#  None,
#  '48분',
#  '50분',
#  '60분',
#  '40분',
#  '25분',
# ...

# %%
#사용시간을 분 단위로 조정하는 함수

def convert_time_minute(time):
    try:
        if '시간' in time:
            hour= time.split('시간')[0]
            if '분' in time:
                minute = time.split('시간')[-1].split('분')[0]
            else:
                minute = 0
        else:
            hour =0
            minute =time.split('분')[0]
            
        return int(hour)*60 + int(minute)
    except:
        return None

# %%
new_use_time_list=[]
for time in use_time_list:
    value =convert_time_minute(time)
    new_use_time_list.append(value)

print(len(new_use_time_list))
print(new_use_time_list[0:10])
# Out:
# 400
# [70, 120, 25, 40, 60, 60, 30, 40, 30, 42]

# %%
#무선 청소기 흡입력 단위 통일
def get_suction(value):
    try:
        value =value.upper()
        if "AW" in value or "W" in value:
            result = value.replace("A","").replace("W","")
            result = int(result.replace(",",""))
        
        elif "PA" in value:
            result = value.replace("PA","")
            result = int(result.replace(",",""))/100
        
        else:
            result =None
        return result
    except:
        return None

# %%
new_suction_list =[]
for power in suction_list:
    value = get_suction(power)
    new_suction_list.append(value)

# %%
print(len(new_suction_list))
print(new_suction_list[:10])
# Out:
# 400
# [220.0, 200, 168.0, 155, 200, 220.0, 120.0, 100, 70.0, None]

# %%
pd_data=pd.DataFrame()
pd_data['카테고리']= category_list
pd_data['회사명']= company_list
pd_data['제품']= product_list
pd_data['가격']= data['가격']
pd_data['사용시간']= new_use_time_list
pd_data['흡입력']= new_suction_list
pd_data.head()
# Out:
#        카테고리   회사명                     제품       가격   사용시간    흡입력
# 0  핸디/스틱청소기   델로라            V11 파워 300W   134610   70.0  220.0
# 1  핸디/스틱청소기  LG전자         코드제로 A9S A9700  1031640  120.0  200.0
# 2    차량용청소기   샤오미  차량용 청소기 무선 3세대 (해외구매)    59850   25.0  168.0
# 3  핸디/스틱청소기   다이슨                 V8 플러피   435610   40.0  155.0
# 4  핸디/스틱청소기  LG전자         코드제로 A9S A9300   669250   60.0  200.0

# %%
pd_data['카테고리'].value_counts()
# Out:
# 핸디/스틱청소기    324
# 물걸레청소기       41
# 차량용청소기       19
# 업소용청소기        7
# 침구청소기         6
# 로봇청소기         2
# 진공청소기         1
# Name: 카테고리, dtype: int64

# %%
pd_data_final = pd_data[pd_data['카테고리'].isin(['핸디/스틱청소기'])]
len(pd_data_final)
# Out:
# 324

# %%
pd_data_final.to_excel('G:/데이터분석 실무_08/datasalon-master/datasalon-master/6_Best_Product/3_2_danawa_data_final.xlsx', index=False)

# %%
import pandas as pd
danawa_data=pd.read_excel('G:/데이터분석 실무_08/datasalon-master/datasalon-master/6_Best_Product/3_2_danawa_data_final.xlsx')
danawa_data.head()
# Out:
#        카테고리   회사명              제품       가격   사용시간    흡입력
# 0  핸디/스틱청소기   델로라     V11 파워 300W   134610   70.0  220.0
# 1  핸디/스틱청소기  LG전자  코드제로 A9S A9700  1031640  120.0  200.0
# 2  핸디/스틱청소기   다이슨          V8 플러피   435610   40.0  155.0
# 3  핸디/스틱청소기  LG전자  코드제로 A9S A9300   669250   60.0  200.0
# 4  핸디/스틱청소기   샤오미         드리미 V10   160010   60.0  220.0

# %%
top_list=danawa_data.sort_values(['흡입력'], ascending =False)
top_list.head()
# Out:
#          카테고리  회사명               제품      가격  사용시간    흡입력
# 47   핸디/스틱청소기  캐치웰           NEW F8  236550  25.0  290.0
# 105  핸디/스틱청소기  아이룸              RS7  219000   NaN  260.0
# 11   핸디/스틱청소기  샤오미  SHUNZAO Z11 PRO  174990  60.0  260.0
# 35   핸디/스틱청소기  샤오미      SHUNZAO Z11  154300  60.0  260.0
# 126  핸디/스틱청소기  아이닉              i20  239000  50.0  250.0

# %%
top_list=danawa_data.sort_values(['사용시간'], ascending =False)
top_list.head()
# Out:
#          카테고리   회사명                제품      가격   사용시간    흡입력
# 108  핸디/스틱청소기  삼성전자    제트 VS20T9279S6  872890  120.0  200.0
# 239  핸디/스틱청소기   샤오미         이지에 YE-01   28500  120.0    NaN
# 44   핸디/스틱청소기  LG전자    코드제로 A9S A9400  779670  120.0  200.0
# 19   핸디/스틱청소기  삼성전자  제트 VS20T9279S6CS  982550  120.0  200.0
# 25   핸디/스틱청소기  LG전자    코드제로 A9S A9500  848300  120.0  200.0

# %%
top_list=danawa_data.sort_values(['흡입력','사용시간'], ascending =False)
top_list.head()
# Out:
#          카테고리  회사명               제품      가격  사용시간    흡입력
# 47   핸디/스틱청소기  캐치웰           NEW F8  236550  25.0  290.0
# 11   핸디/스틱청소기  샤오미  SHUNZAO Z11 PRO  174990  60.0  260.0
# 35   핸디/스틱청소기  샤오미      SHUNZAO Z11  154300  60.0  260.0
# 105  핸디/스틱청소기  아이룸              RS7  219000   NaN  260.0
# 31   핸디/스틱청소기  샤오미          드리미 V11  286100  90.0  250.0

# %%
price_mead_value=danawa_data['가격'].mean()
suction_mead_value=danawa_data['흡입력'].mean()
use_time_mead_value=danawa_data['사용시간'].mean()

print("가격 평균값", price_mead_value)
print("흡입력 평균값", suction_mead_value)
print("사용시간 평균값", use_time_mead_value)
# Out:
# 가격 평균값 341095.06172839506
# 흡입력 평균값 154.775956284153
# 사용시간 평균값 45.76897689768977

# %%
condition_data=danawa_data[
    (danawa_data['가격']<= price_mead_value)&
    (danawa_data['흡입력']>= suction_mead_value)&
    (danawa_data['사용시간']>=use_time_mead_value)
]

condition_data
# Out:
#          카테고리    회사명                   제품      가격  사용시간    흡입력
# 0    핸디/스틱청소기    델로라          V11 파워 300W  134610  70.0  220.0
# 4    핸디/스틱청소기    샤오미              드리미 V10  160010  60.0  220.0
# 11   핸디/스틱청소기    샤오미      SHUNZAO Z11 PRO  174990  60.0  260.0
# 23   핸디/스틱청소기    샤오미               드리미 V9  123440  60.0  200.0
# 31   핸디/스틱청소기    샤오미              드리미 V11  286100  90.0  250.0
# 35   핸디/스틱청소기    샤오미          SHUNZAO Z11  154300  60.0  260.0
# 42   핸디/스틱청소기    샤오미             드리미 V10P  289000  60.0  220.0
# 57   핸디/스틱청소기    샤오미              로이드미 제로  221030  60.0  220.0
# 62   핸디/스틱청소기  원더스리빙          원더스 다이나킹 Z9  299000  65.0  220.0
# 112  핸디/스틱청소기    샤오미              드리미 V9P  215250  60.0  200.0
# 123  핸디/스틱청소기    캐치웰                 코드엑스  229000  60.0  220.0
# 126  핸디/스틱청소기    아이닉                  i20  239000  50.0  250.0
# 142  핸디/스틱청소기  DIBEA                PLA25  246040  50.0  250.0
# 152  핸디/스틱청소기  DIBEA              M500 퀀텀  246900  50.0  250.0
# ...
